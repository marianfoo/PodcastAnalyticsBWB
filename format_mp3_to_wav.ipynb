# %%
from os import path
from pydub import AudioSegment
import os

# %%
AudioSegment.converter = r"C:\FFmpeg\bin\ffmpeg.exe"
AudioSegment.ffmpeg = r"C:\FFmpeg\bin\ffmpeg.exe"
AudioSegment.ffprobe = r"C:\FFmpeg\bin\ffprobe.exe"

# %%
for filename in os.listdir(r"E:\files\\spotify"):
    number = filename.split("_")[1].split(".")[0]
    filename_wav = "bwb_" + number + ".wav"
    path_org = r'E:\files\\spotify\{}'.format(filename)  
    path_small = r'E:\files\\spotify_small\{}'.format(filename)  
    path_wav = r'E:\files\\spotify_wav\{}'.format(filename_wav)  
    sound = AudioSegment.from_mp3(path_org)
    sound.export(path_small, format='mp3', parameters=["-ac","2","-ar","8000"])
    sound_small = AudioSegment.from_mp3(path_small)
    sound_small.export(path_wav, format="wav")
    print(filename)
# Out:
# bwb_001.mp3
# bwb_002.mp3
# bwb_003.mp3
# bwb_004.mp3
# bwb_005.mp3
# bwb_006.mp3
# bwb_007.mp3
# bwb_008.mp3
# bwb_009.mp3
# bwb_010.mp3
# bwb_011.mp3
# bwb_012.mp3
# bwb_013.mp3
# bwb_014.mp3
# bwb_015.mp3
# bwb_016.mp3
# bwb_017.mp3
# bwb_018.mp3
# bwb_019.mp3
# bwb_020.mp3
# bwb_021.mp3
# bwb_022.mp3
# bwb_023.mp3
# bwb_024.mp3
# bwb_025.mp3
# bwb_026.mp3
# bwb_027.mp3
# bwb_028.mp3
# bwb_029.mp3
# bwb_030.mp3
# bwb_031.mp3
# bwb_032.mp3
# bwb_033.mp3
# bwb_034.mp3
# bwb_035.mp3
# bwb_036.mp3
# bwb_037.mp3
# bwb_038.mp3
# bwb_039.mp3
# bwb_040.mp3
# bwb_041.mp3
# bwb_042.mp3
# bwb_043.mp3
# bwb_044.mp3
# bwb_045.mp3
# bwb_046.mp3
# bwb_047.mp3
# bwb_048.mp3
# bwb_049.mp3
# bwb_050.mp3
# bwb_051.mp3
# bwb_052.mp3
# bwb_053.mp3
# bwb_054.mp3
# bwb_055.mp3
# bwb_056.mp3
# bwb_057.mp3
# bwb_058.mp3
# bwb_059.mp3
# bwb_060.mp3
# bwb_061.mp3
# bwb_062.mp3
# bwb_063.mp3
# bwb_064.mp3
# bwb_065.mp3
# bwb_066.mp3
# bwb_067.mp3
# bwb_068.mp3
# bwb_069.mp3
# bwb_070.mp3
# bwb_071.mp3
# ...
